# %%
import pandas as pd
import csv
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers, Model
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping

# %%
def load_data(v):
    with open(f'mutation_dataset_10-06_v{v}\\simulacoes_com_erro.pkl', 'rb') as arquivo:
        simulacoes_com_erro = pickle.load(arquivo)

    trees_cblv = np.load(f'mutation_dataset_10-06_v{v}\\tree_data.npy')
    trees_cblv = np.delete(trees_cblv, simulacoes_com_erro, axis=0)

    #R_0_1, infectuos time and a taxa relativa 
    # Retornando a segunda coluna (coluna referente ao R_nought)
    # e em segunda transformando a lista em um np.array

    tabela_de_parametros = np.load(f'mutation_dataset_10-06_v{v}\\tabela_parametros.npy')
    tabela_de_parametros = np.delete(tabela_de_parametros, simulacoes_com_erro, axis=0)

    R_nought1 = np.array([sublist[0] for sublist in tabela_de_parametros])
    R_nought2 = np.array([sublist[1] for sublist in tabela_de_parametros])
    infectious_time = np.array([sublist[8] for sublist in tabela_de_parametros])
    proportion_tr11_tr22 = np.array([sublist[10] for sublist in tabela_de_parametros])
    
    rescale_factors = np.load(f'mutation_dataset_10-06_v{v}\\rescale_factor.npy')
    rescale_factors = np.delete(rescale_factors, simulacoes_com_erro)

    infectious_time_div_reascale = np.round(infectious_time / rescale_factors, 3)

    mutation_masks = np.load(f'mutation_dataset_10-06_v{v}\\mutation_masks.npy')
    mutation_masks = np.delete(mutation_masks, simulacoes_com_erro, axis=0)

    vectorized = np.column_stack((R_nought1, infectious_time_div_reascale, proportion_tr11_tr22))

    return trees_cblv, vectorized, mutation_masks, rescale_factors

# %%
X, y_param, y_mask, rescale_factors = load_data(0)

# %%
test_size = 0.1
(X_train, X_test, y_param_train, y_param_test, y_mask_train, y_mask_test) = train_test_split(
    X, y_param, y_mask, test_size=test_size, shuffle=False)

# %%
y_mask_train = y_mask_train.reshape(-1, 501, 2)
y_mask_test = y_mask_test.reshape(-1, 501, 2)

# %%
scaler = StandardScaler()

y_param_train_scaled = scaler.fit_transform(y_param_train)
y_param_test_scaled = scaler.transform(y_param_test)

# %%
#Essa arquitetura usará cross-task feature fusion, as FEATURES da mask head irão ser concatenadas com as features da parameter head.

# Não repetir quando eu upar dados novos
inputs = layers.Input(shape=X_train[0].shape)
# Shared backbone
x = layers.Reshape((501, 2))(inputs)
x = layers.Conv1D(filters=50, kernel_size=3, activation='relu', padding='same')(x)
x = layers.Conv1D(filters=50, kernel_size=10, activation='relu', padding='same')(x)


#Mask head
m = layers.Conv1D(filters=32, kernel_size=3, activation='relu', padding='same')(x)
mask_output = layers.Conv1D(filters=2, kernel_size=1, activation='sigmoid', padding='same', name='mask')(m)

# as features da mask head serão concatenadas com as features da parameter head.
mask_features = layers.GlobalAveragePooling1D()(m)



#parameters head 
p = layers.MaxPooling1D(pool_size=10)(x)
p = layers.Conv1D(filters=80, kernel_size=10, activation='relu', padding='same')(p)
p = layers.GlobalAveragePooling1D()(p)
#-------------------------------------------------
# Concatenate parameter features with mask features
p = layers.Concatenate()([p, mask_features])
#-------------------------------------------------
p = layers.Dense(64, activation='elu')(p) 
p = layers.Dense(32, activation='elu')(p) 
p = layers.Dense(16, activation='elu')(p) 
p = layers.Dense(8, activation='elu')(p)
parameter_output = layers.Dense(3, activation='linear', name='parameters')(p)



modelo = Model(inputs=inputs, outputs=[parameter_output, mask_output])
modelo.compile(optimizer='adam', loss={'parameters': 'mse', 'mask': 'binary_crossentropy'},
               loss_weights={'parameters': 1.0, 'mask': 1.0}, metrics={'parameters': ['mae'], 'mask': ['accuracy']})
modelo.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 1002)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 501, 2)    │          0 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 501, 50)   │        350 │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 501, 50)   │     25,050 │ conv1d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 50, 50)    │          0 │ conv1d_1[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 50, 80)    │     40,080 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 501, 32)   │      4,832 │ conv1d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 80)        │          0 │ conv1d_3[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ conv1d_2[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 112)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │      7,232 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 32)        │      2,080 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 16)        │        528 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 8)         │        136 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ parameters (Dense)  │ (None, 3)         │         27 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mask (Conv1D)       │ (None, 501, 2)    │         66 │ conv1d_2[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 80,381 (313.99 KB)
#  Trainable params: 80,381 (313.99 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=20, restore_best_weights=True, verbose=1)

# %%
history = modelo.fit(
    X_train, [y_param_train_scaled, y_mask_train],
    validation_data=(X_test,[y_param_test_scaled, y_mask_test]),
    epochs=100, batch_size=32, callbacks=[early_stop])
# Out:
# Epoch 1/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 175s 61ms/step - loss: 3.1302 - mask_accuracy: 0.4730 - mask_loss: 0.1920 - parameters_loss: 2.9381 - parameters_mae: 1.1332 - val_loss: 5.4530 - val_mask_accuracy: 0.4936 - val_mask_loss: 0.1304 - val_parameters_loss: 5.3215 - val_parameters_mae: 1.2560
# Epoch 2/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 182s 65ms/step - loss: 5.4596 - mask_accuracy: 0.5223 - mask_loss: 0.1243 - parameters_loss: 5.3354 - parameters_mae: 1.2574 - val_loss: 5.4426 - val_mask_accuracy: 0.5408 - val_mask_loss: 0.1220 - val_parameters_loss: 5.3196 - val_parameters_mae: 1.2334
# Epoch 3/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 194s 69ms/step - loss: 5.4482 - mask_accuracy: 0.5408 - mask_loss: 0.1182 - parameters_loss: 5.3301 - parameters_mae: 1.2296 - val_loss: 5.4431 - val_mask_accuracy: 0.5907 - val_mask_loss: 0.1182 - val_parameters_loss: 5.3239 - val_parameters_mae: 1.9947
# Epoch 4/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 215s 76ms/step - loss: 5.4395 - mask_accuracy: 0.6074 - mask_loss: 0.1153 - parameters_loss: 5.3242 - parameters_mae: 2.0682 - val_loss: 5.4381 - val_mask_accuracy: 0.5732 - val_mask_loss: 0.1131 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.0898
# Epoch 5/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 227s 81ms/step - loss: 5.4132 - mask_accuracy: 0.5582 - mask_loss: 0.1128 - parameters_loss: 5.3004 - parameters_mae: 2.0849 - val_loss: 5.4398 - val_mask_accuracy: 0.6193 - val_mask_loss: 0.1148 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.1184
# Epoch 6/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 225s 80ms/step - loss: 5.3951 - mask_accuracy: 0.5645 - mask_loss: 0.1113 - parameters_loss: 5.2837 - parameters_mae: 2.1023 - val_loss: 5.4366 - val_mask_accuracy: 0.6707 - val_mask_loss: 0.1116 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.1020
# Epoch 7/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 180s 64ms/step - loss: 5.4264 - mask_accuracy: 0.5983 - mask_loss: 0.1103 - parameters_loss: 5.3161 - parameters_mae: 2.0964 - val_loss: 5.4377 - val_mask_accuracy: 0.5798 - val_mask_loss: 0.1127 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.0847
# Epoch 8/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 185s 66ms/step - loss: 5.4137 - mask_accuracy: 0.5974 - mask_loss: 0.1096 - parameters_loss: 5.3040 - parameters_mae: 2.1167 - val_loss: 5.4354 - val_mask_accuracy: 0.5814 - val_mask_loss: 0.1104 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.1384
# Epoch 9/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 171s 61ms/step - loss: 5.4362 - mask_accuracy: 0.6071 - mask_loss: 0.1090 - parameters_loss: 5.3272 - parameters_mae: 2.1349 - val_loss: 5.4355 - val_mask_accuracy: 0.6628 - val_mask_loss: 0.1105 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.1326
# Epoch 10/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 171s 61ms/step - loss: 5.4183 - mask_accuracy: 0.6107 - mask_loss: 0.1088 - parameters_loss: 5.3095 - parameters_mae: 2.1570 - val_loss: 5.4360 - val_mask_accuracy: 0.6078 - val_mask_loss: 0.1110 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.1837
# Epoch 11/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 167s 59ms/step - loss: 5.4328 - mask_accuracy: 0.6026 - mask_loss: 0.1086 - parameters_loss: 5.3242 - parameters_mae: 2.1778 - val_loss: 5.4342 - val_mask_accuracy: 0.5131 - val_mask_loss: 0.1092 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.1980
# Epoch 12/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 169s 60ms/step - loss: 5.4148 - mask_accuracy: 0.5983 - mask_loss: 0.1086 - parameters_loss: 5.3063 - parameters_mae: 2.1997 - val_loss: 5.4345 - val_mask_accuracy: 0.5899 - val_mask_loss: 0.1095 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.2074
# Epoch 13/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 166s 59ms/step - loss: 5.4038 - mask_accuracy: 0.5923 - mask_loss: 0.1082 - parameters_loss: 5.2955 - parameters_mae: 2.2236 - val_loss: 5.4343 - val_mask_accuracy: 0.5888 - val_mask_loss: 0.1092 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.2342
# Epoch 14/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 167s 60ms/step - loss: 5.4196 - mask_accuracy: 0.5761 - mask_loss: 0.1074 - parameters_loss: 5.3122 - parameters_mae: 2.2454 - val_loss: 5.4331 - val_mask_accuracy: 0.5907 - val_mask_loss: 0.1081 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.2460
# Epoch 15/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 166s 59ms/step - loss: 5.4181 - mask_accuracy: 0.5666 - mask_loss: 0.1078 - parameters_loss: 5.3103 - parameters_mae: 2.2661 - val_loss: 5.4339 - val_mask_accuracy: 0.5511 - val_mask_loss: 0.1089 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.2593
# Epoch 16/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 162s 57ms/step - loss: 5.4460 - mask_accuracy: 0.5629 - mask_loss: 0.1074 - parameters_loss: 5.3385 - parameters_mae: 2.2950 - val_loss: 5.4372 - val_mask_accuracy: 0.6497 - val_mask_loss: 0.1122 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.3144
# Epoch 17/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 160s 57ms/step - loss: 5.3840 - mask_accuracy: 0.5658 - mask_loss: 0.1081 - parameters_loss: 5.2759 - parameters_mae: 2.3135 - val_loss: 5.4340 - val_mask_accuracy: 0.4715 - val_mask_loss: 0.1090 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.3566
# Epoch 18/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 165s 59ms/step - loss: 5.3847 - mask_accuracy: 0.5513 - mask_loss: 0.1076 - parameters_loss: 5.2771 - parameters_mae: 2.3432 - val_loss: 5.4367 - val_mask_accuracy: 0.5456 - val_mask_loss: 0.1117 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.3650
# Epoch 19/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 174s 62ms/step - loss: 5.4439 - mask_accuracy: 0.5544 - mask_loss: 0.1071 - parameters_loss: 5.3368 - parameters_mae: 2.3742 - val_loss: 5.4327 - val_mask_accuracy: 0.5053 - val_mask_loss: 0.1077 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.3937
# Epoch 20/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 176s 63ms/step - loss: 5.4368 - mask_accuracy: 0.5538 - mask_loss: 0.1069 - parameters_loss: 5.3298 - parameters_mae: 2.4002 - val_loss: 5.4324 - val_mask_accuracy: 0.5244 - val_mask_loss: 0.1074 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.4061
# Epoch 21/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 189s 67ms/step - loss: 5.4269 - mask_accuracy: 0.5597 - mask_loss: 0.1068 - parameters_loss: 5.3202 - parameters_mae: 2.4166 - val_loss: 5.4349 - val_mask_accuracy: 0.6423 - val_mask_loss: 0.1099 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.3885
# Epoch 22/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 172s 61ms/step - loss: 5.4186 - mask_accuracy: 0.5670 - mask_loss: 0.1072 - parameters_loss: 5.3114 - parameters_mae: 2.4441 - val_loss: 5.4329 - val_mask_accuracy: 0.5640 - val_mask_loss: 0.1079 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.4752
# Epoch 23/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 179s 64ms/step - loss: 5.4006 - mask_accuracy: 0.5708 - mask_loss: 0.1068 - parameters_loss: 5.2939 - parameters_mae: 2.4669 - val_loss: 5.4348 - val_mask_accuracy: 0.6258 - val_mask_loss: 0.1098 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.4508
# Epoch 24/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 167s 60ms/step - loss: 5.4388 - mask_accuracy: 0.5759 - mask_loss: 0.1067 - parameters_loss: 5.3320 - parameters_mae: 2.4948 - val_loss: 5.4329 - val_mask_accuracy: 0.6364 - val_mask_loss: 0.1079 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.4835
# Epoch 25/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 163s 58ms/step - loss: 5.4495 - mask_accuracy: 0.5954 - mask_loss: 0.1066 - parameters_loss: 5.3429 - parameters_mae: 2.5202 - val_loss: 5.4337 - val_mask_accuracy: 0.6077 - val_mask_loss: 0.1087 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.4953
# Epoch 26/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 163s 58ms/step - loss: 5.3983 - mask_accuracy: 0.6056 - mask_loss: 0.1072 - parameters_loss: 5.2911 - parameters_mae: 2.5444 - val_loss: 5.4330 - val_mask_accuracy: 0.5953 - val_mask_loss: 0.1080 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.5809
# Epoch 27/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 170s 60ms/step - loss: 5.4388 - mask_accuracy: 0.6407 - mask_loss: 0.1071 - parameters_loss: 5.3317 - parameters_mae: 2.5713 - val_loss: 5.4343 - val_mask_accuracy: 0.5994 - val_mask_loss: 0.1092 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.6210
# Epoch 28/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 186s 66ms/step - loss: 5.3911 - mask_accuracy: 0.6448 - mask_loss: 0.1073 - parameters_loss: 5.2837 - parameters_mae: 2.5920 - val_loss: 5.4330 - val_mask_accuracy: 0.6518 - val_mask_loss: 0.1080 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.6110
# Epoch 29/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 186s 66ms/step - loss: 5.4319 - mask_accuracy: 0.6707 - mask_loss: 0.1067 - parameters_loss: 5.3252 - parameters_mae: 2.6221 - val_loss: 5.4328 - val_mask_accuracy: 0.6764 - val_mask_loss: 0.1078 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.6166
# Epoch 30/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 168s 60ms/step - loss: 5.4239 - mask_accuracy: 0.6767 - mask_loss: 0.1064 - parameters_loss: 5.3175 - parameters_mae: 2.6482 - val_loss: 5.4320 - val_mask_accuracy: 0.7164 - val_mask_loss: 0.1070 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.6709
# Epoch 31/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 172s 61ms/step - loss: 5.4204 - mask_accuracy: 0.6904 - mask_loss: 0.1055 - parameters_loss: 5.3149 - parameters_mae: 2.6784 - val_loss: 5.4336 - val_mask_accuracy: 0.7348 - val_mask_loss: 0.1086 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.7064
# Epoch 32/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 178s 63ms/step - loss: 5.4334 - mask_accuracy: 0.7171 - mask_loss: 0.1062 - parameters_loss: 5.3272 - parameters_mae: 2.6992 - val_loss: 5.4325 - val_mask_accuracy: 0.7587 - val_mask_loss: 0.1075 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.7325
# Epoch 33/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 209s 74ms/step - loss: 5.4441 - mask_accuracy: 0.7210 - mask_loss: 0.1062 - parameters_loss: 5.3379 - parameters_mae: 2.7283 - val_loss: 5.4363 - val_mask_accuracy: 0.6653 - val_mask_loss: 0.1113 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.7996
# Epoch 34/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 220s 78ms/step - loss: 5.4282 - mask_accuracy: 0.7244 - mask_loss: 0.1064 - parameters_loss: 5.3218 - parameters_mae: 2.7611 - val_loss: 5.4325 - val_mask_accuracy: 0.7304 - val_mask_loss: 0.1075 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.8120
# Epoch 35/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 184s 65ms/step - loss: 5.4241 - mask_accuracy: 0.7461 - mask_loss: 0.1059 - parameters_loss: 5.3182 - parameters_mae: 2.7881 - val_loss: 5.4317 - val_mask_accuracy: 0.7324 - val_mask_loss: 0.1067 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.8044
# Epoch 36/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 177s 63ms/step - loss: 5.4025 - mask_accuracy: 0.7492 - mask_loss: 0.1062 - parameters_loss: 5.2963 - parameters_mae: 2.8065 - val_loss: 5.4326 - val_mask_accuracy: 0.7730 - val_mask_loss: 0.1076 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.8032
# Epoch 37/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 188s 67ms/step - loss: 5.4273 - mask_accuracy: 0.7412 - mask_loss: 0.1060 - parameters_loss: 5.3212 - parameters_mae: 2.8361 - val_loss: 5.4326 - val_mask_accuracy: 0.7373 - val_mask_loss: 0.1076 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.8778
# Epoch 38/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 189s 67ms/step - loss: 5.3917 - mask_accuracy: 0.7529 - mask_loss: 0.1066 - parameters_loss: 5.2851 - parameters_mae: 2.8549 - val_loss: 5.4332 - val_mask_accuracy: 0.6989 - val_mask_loss: 0.1082 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.9414
# Epoch 39/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 200s 71ms/step - loss: 5.3953 - mask_accuracy: 0.7506 - mask_loss: 0.1066 - parameters_loss: 5.2887 - parameters_mae: 2.8963 - val_loss: 5.4346 - val_mask_accuracy: 0.8508 - val_mask_loss: 0.1096 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.9300
# Epoch 40/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 198s 70ms/step - loss: 5.3968 - mask_accuracy: 0.7606 - mask_loss: 0.1065 - parameters_loss: 5.2903 - parameters_mae: 2.9131 - val_loss: 5.4350 - val_mask_accuracy: 0.7797 - val_mask_loss: 0.1100 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.8560
# Epoch 41/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 171s 61ms/step - loss: 5.4265 - mask_accuracy: 0.7460 - mask_loss: 0.1055 - parameters_loss: 5.3210 - parameters_mae: 2.9501 - val_loss: 5.4322 - val_mask_accuracy: 0.6948 - val_mask_loss: 0.1072 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.9642
# Epoch 42/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 175s 62ms/step - loss: 5.4148 - mask_accuracy: 0.7308 - mask_loss: 0.1060 - parameters_loss: 5.3088 - parameters_mae: 2.9782 - val_loss: 5.4321 - val_mask_accuracy: 0.6475 - val_mask_loss: 0.1071 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.0173
# Epoch 43/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 177s 63ms/step - loss: 5.4213 - mask_accuracy: 0.7164 - mask_loss: 0.1056 - parameters_loss: 5.3157 - parameters_mae: 3.0024 - val_loss: 5.4327 - val_mask_accuracy: 0.7832 - val_mask_loss: 0.1077 - val_parameters_loss: 5.3239 - val_parameters_mae: 2.9759
# Epoch 44/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 206s 73ms/step - loss: 5.4034 - mask_accuracy: 0.7334 - mask_loss: 0.1062 - parameters_loss: 5.2972 - parameters_mae: 3.0244 - val_loss: 5.4328 - val_mask_accuracy: 0.7926 - val_mask_loss: 0.1078 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.0786
# Epoch 45/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 186s 66ms/step - loss: 5.4265 - mask_accuracy: 0.7279 - mask_loss: 0.1069 - parameters_loss: 5.3197 - parameters_mae: 3.0496 - val_loss: 5.4317 - val_mask_accuracy: 0.7279 - val_mask_loss: 0.1067 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.0570
# Epoch 46/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 181s 64ms/step - loss: 5.3956 - mask_accuracy: 0.7035 - mask_loss: 0.1064 - parameters_loss: 5.2893 - parameters_mae: 3.0794 - val_loss: 5.4326 - val_mask_accuracy: 0.6557 - val_mask_loss: 0.1076 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.1346
# Epoch 47/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 180s 64ms/step - loss: 5.4299 - mask_accuracy: 0.7164 - mask_loss: 0.1063 - parameters_loss: 5.3236 - parameters_mae: 3.1140 - val_loss: 5.4318 - val_mask_accuracy: 0.7358 - val_mask_loss: 0.1068 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.0957
# Epoch 48/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 180s 64ms/step - loss: 5.4008 - mask_accuracy: 0.7130 - mask_loss: 0.1056 - parameters_loss: 5.2952 - parameters_mae: 3.1345 - val_loss: 5.4317 - val_mask_accuracy: 0.6544 - val_mask_loss: 0.1067 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.1717
# Epoch 49/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 180s 64ms/step - loss: 5.4388 - mask_accuracy: 0.7161 - mask_loss: 0.1064 - parameters_loss: 5.3324 - parameters_mae: 3.1660 - val_loss: 5.4317 - val_mask_accuracy: 0.6644 - val_mask_loss: 0.1067 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.1861
# Epoch 50/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 178s 63ms/step - loss: 5.4083 - mask_accuracy: 0.7307 - mask_loss: 0.1059 - parameters_loss: 5.3024 - parameters_mae: 3.1932 - val_loss: 5.4329 - val_mask_accuracy: 0.6329 - val_mask_loss: 0.1079 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.1841
# Epoch 51/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 183s 65ms/step - loss: 5.4241 - mask_accuracy: 0.7064 - mask_loss: 0.1049 - parameters_loss: 5.3192 - parameters_mae: 3.2259 - val_loss: 5.4315 - val_mask_accuracy: 0.7247 - val_mask_loss: 0.1065 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.2459
# Epoch 52/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 178s 63ms/step - loss: 5.4392 - mask_accuracy: 0.7272 - mask_loss: 0.1055 - parameters_loss: 5.3337 - parameters_mae: 3.2533 - val_loss: 5.4320 - val_mask_accuracy: 0.7995 - val_mask_loss: 0.1070 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.2968
# Epoch 53/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 179s 63ms/step - loss: 5.4232 - mask_accuracy: 0.7288 - mask_loss: 0.1055 - parameters_loss: 5.3177 - parameters_mae: 3.2822 - val_loss: 5.4319 - val_mask_accuracy: 0.8145 - val_mask_loss: 0.1069 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.2694
# Epoch 54/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 179s 64ms/step - loss: 5.4047 - mask_accuracy: 0.7322 - mask_loss: 0.1055 - parameters_loss: 5.2992 - parameters_mae: 3.3047 - val_loss: 5.4320 - val_mask_accuracy: 0.6907 - val_mask_loss: 0.1070 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.2963
# Epoch 55/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 181s 64ms/step - loss: 5.4121 - mask_accuracy: 0.7181 - mask_loss: 0.1063 - parameters_loss: 5.3058 - parameters_mae: 3.3252 - val_loss: 5.4319 - val_mask_accuracy: 0.7136 - val_mask_loss: 0.1069 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.3672
# Epoch 56/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 181s 64ms/step - loss: 5.4264 - mask_accuracy: 0.7274 - mask_loss: 0.1058 - parameters_loss: 5.3205 - parameters_mae: 3.3604 - val_loss: 5.4318 - val_mask_accuracy: 0.8319 - val_mask_loss: 0.1068 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.3755
# Epoch 57/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 203s 65ms/step - loss: 5.4199 - mask_accuracy: 0.7255 - mask_loss: 0.1058 - parameters_loss: 5.3140 - parameters_mae: 3.3926 - val_loss: 5.4319 - val_mask_accuracy: 0.6821 - val_mask_loss: 0.1069 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.4510
# Epoch 58/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 182s 65ms/step - loss: 5.4370 - mask_accuracy: 0.7245 - mask_loss: 0.1053 - parameters_loss: 5.3317 - parameters_mae: 3.4178 - val_loss: 5.4319 - val_mask_accuracy: 0.7528 - val_mask_loss: 0.1069 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.4812
# Epoch 59/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 183s 65ms/step - loss: 5.4001 - mask_accuracy: 0.7127 - mask_loss: 0.1061 - parameters_loss: 5.2939 - parameters_mae: 3.4376 - val_loss: 5.4324 - val_mask_accuracy: 0.7591 - val_mask_loss: 0.1074 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.4963
# Epoch 60/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 196s 70ms/step - loss: 5.4317 - mask_accuracy: 0.7160 - mask_loss: 0.1062 - parameters_loss: 5.3255 - parameters_mae: 3.4801 - val_loss: 5.4317 - val_mask_accuracy: 0.7185 - val_mask_loss: 0.1067 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.5041
# Epoch 61/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 182s 65ms/step - loss: 5.4011 - mask_accuracy: 0.7163 - mask_loss: 0.1067 - parameters_loss: 5.2944 - parameters_mae: 3.4989 - val_loss: 5.4338 - val_mask_accuracy: 0.6549 - val_mask_loss: 0.1087 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.5740
# Epoch 62/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 181s 64ms/step - loss: 5.4283 - mask_accuracy: 0.7146 - mask_loss: 0.1060 - parameters_loss: 5.3223 - parameters_mae: 3.5301 - val_loss: 5.4335 - val_mask_accuracy: 0.7365 - val_mask_loss: 0.1085 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.5974
# Epoch 63/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 183s 65ms/step - loss: 5.4170 - mask_accuracy: 0.7122 - mask_loss: 0.1057 - parameters_loss: 5.3113 - parameters_mae: 3.5610 - val_loss: 5.4318 - val_mask_accuracy: 0.7747 - val_mask_loss: 0.1068 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.5767
# Epoch 64/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 184s 65ms/step - loss: 5.4158 - mask_accuracy: 0.7244 - mask_loss: 0.1062 - parameters_loss: 5.3096 - parameters_mae: 3.5844 - val_loss: 5.4315 - val_mask_accuracy: 0.7174 - val_mask_loss: 0.1065 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.5784
# Epoch 65/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 184s 65ms/step - loss: 5.4310 - mask_accuracy: 0.7205 - mask_loss: 0.1063 - parameters_loss: 5.3247 - parameters_mae: 3.6100 - val_loss: 5.4325 - val_mask_accuracy: 0.6484 - val_mask_loss: 0.1075 - val_parameters_loss: 5.3239 - val_parameters_mae: 3.6893
# Epoch 66/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 184s 66ms/step - loss: 6.7809 - mask_accuracy: 0.7226 - mask_loss: 0.1059 - parameters_loss: 6.6750 - parameters_mae: 5.4215 - val_loss: 10.9358 - val_mask_accuracy: 0.7959 - val_mask_loss: 0.1066 - val_parameters_loss: 10.8312 - val_parameters_mae: 10.1832
# Epoch 67/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 185s 66ms/step - loss: 10.7496 - mask_accuracy: 0.7256 - mask_loss: 0.1055 - parameters_loss: 10.6441 - parameters_mae: 10.1375 - val_loss: 10.9359 - val_mask_accuracy: 0.6633 - val_mask_loss: 0.1067 - val_parameters_loss: 10.8312 - val_parameters_mae: 10.1407
# Epoch 68/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 185s 66ms/step - loss: 10.7421 - mask_accuracy: 0.7253 - mask_loss: 0.1053 - parameters_loss: 10.6368 - parameters_mae: 10.0770 - val_loss: 10.9356 - val_mask_accuracy: 0.6868 - val_mask_loss: 0.1064 - val_parameters_loss: 10.8312 - val_parameters_mae: 10.0469
# Epoch 69/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 185s 66ms/step - loss: 10.7791 - mask_accuracy: 0.7138 - mask_loss: 0.1050 - parameters_loss: 10.6741 - parameters_mae: 10.1827 - val_loss: 10.9359 - val_mask_accuracy: 0.8070 - val_mask_loss: 0.1067 - val_parameters_loss: 10.8312 - val_parameters_mae: 9.9893
# Epoch 70/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 186s 66ms/step - loss: 10.7990 - mask_accuracy: 0.7298 - mask_loss: 0.1065 - parameters_loss: 10.6925 - parameters_mae: 10.2099 - val_loss: 10.9359 - val_mask_accuracy: 0.7547 - val_mask_loss: 0.1067 - val_parameters_loss: 10.8312 - val_parameters_mae: 10.2469
# Epoch 71/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 186s 66ms/step - loss: 10.7231 - mask_accuracy: 0.7289 - mask_loss: 0.1059 - parameters_loss: 10.6172 - parameters_mae: 10.3132 - val_loss: 10.9357 - val_mask_accuracy: 0.7473 - val_mask_loss: 0.1065 - val_parameters_loss: 10.8312 - val_parameters_mae: 10.2313
# Epoch 72/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 187s 66ms/step - loss: 10.7518 - mask_accuracy: 0.7341 - mask_loss: 0.1056 - parameters_loss: 10.6462 - parameters_mae: 10.4079 - val_loss: 10.9358 - val_mask_accuracy: 0.6376 - val_mask_loss: 0.1066 - val_parameters_loss: 10.8312 - val_parameters_mae: 10.6397
# Epoch 73/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 188s 67ms/step - loss: 10.7264 - mask_accuracy: 0.7259 - mask_loss: 0.1055 - parameters_loss: 10.6208 - parameters_mae: 10.4808 - val_loss: 10.9378 - val_mask_accuracy: 0.7703 - val_mask_loss: 0.1086 - val_parameters_loss: 10.8312 - val_parameters_mae: 10.2445
# Epoch 74/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 188s 67ms/step - loss: 10.7597 - mask_accuracy: 0.7307 - mask_loss: 0.1055 - parameters_loss: 10.6542 - parameters_mae: 10.6099 - val_loss: 10.9363 - val_mask_accuracy: 0.7049 - val_mask_loss: 0.1071 - val_parameters_loss: 10.8312 - val_parameters_mae: 10.5807
# Epoch 75/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 189s 67ms/step - loss: 10.7823 - mask_accuracy: 0.7261 - mask_loss: 0.1059 - parameters_loss: 10.6764 - parameters_mae: 10.6596 - val_loss: 10.9374 - val_mask_accuracy: 0.7142 - val_mask_loss: 0.1082 - val_parameters_loss: 10.8312 - val_parameters_mae: 10.8988
# Epoch 76/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 188s 67ms/step - loss: 10.7579 - mask_accuracy: 0.7098 - mask_loss: 0.1062 - parameters_loss: 10.6516 - parameters_mae: 10.7127 - val_loss: 10.9359 - val_mask_accuracy: 0.7321 - val_mask_loss: 0.1067 - val_parameters_loss: 10.8312 - val_parameters_mae: 10.8642
# Epoch 77/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 189s 67ms/step - loss: 10.7939 - mask_accuracy: 0.7275 - mask_loss: 0.1059 - parameters_loss: 10.6880 - parameters_mae: 10.8320 - val_loss: 10.9362 - val_mask_accuracy: 0.7833 - val_mask_loss: 0.1070 - val_parameters_loss: 10.8312 - val_parameters_mae: 11.1486
# Epoch 78/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 190s 67ms/step - loss: 10.7143 - mask_accuracy: 0.7305 - mask_loss: 0.1056 - parameters_loss: 10.6088 - parameters_mae: 10.9106 - val_loss: 10.9371 - val_mask_accuracy: 0.6913 - val_mask_loss: 0.1079 - val_parameters_loss: 10.8312 - val_parameters_mae: 11.1876
# Epoch 79/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 189s 67ms/step - loss: 10.6967 - mask_accuracy: 0.7085 - mask_loss: 0.1053 - parameters_loss: 10.5914 - parameters_mae: 11.0360 - val_loss: 10.9372 - val_mask_accuracy: 0.6613 - val_mask_loss: 0.1080 - val_parameters_loss: 10.8312 - val_parameters_mae: 10.9400
# Epoch 80/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 191s 68ms/step - loss: 10.7853 - mask_accuracy: 0.7182 - mask_loss: 0.1053 - parameters_loss: 10.6799 - parameters_mae: 11.1354 - val_loss: 10.9354 - val_mask_accuracy: 0.7399 - val_mask_loss: 0.1063 - val_parameters_loss: 10.8312 - val_parameters_mae: 11.1155
# Epoch 81/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 190s 68ms/step - loss: 10.7294 - mask_accuracy: 0.7089 - mask_loss: 0.1053 - parameters_loss: 10.6242 - parameters_mae: 11.2083 - val_loss: 10.9358 - val_mask_accuracy: 0.8014 - val_mask_loss: 0.1066 - val_parameters_loss: 10.8312 - val_parameters_mae: 11.0077
# Epoch 82/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 192s 68ms/step - loss: 10.7483 - mask_accuracy: 0.7437 - mask_loss: 0.1053 - parameters_loss: 10.6430 - parameters_mae: 11.2606 - val_loss: 10.9377 - val_mask_accuracy: 0.6848 - val_mask_loss: 0.1085 - val_parameters_loss: 10.8312 - val_parameters_mae: 11.8061
# Epoch 83/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 193s 68ms/step - loss: 10.7132 - mask_accuracy: 0.7332 - mask_loss: 0.1057 - parameters_loss: 10.6074 - parameters_mae: 11.4150 - val_loss: 10.9370 - val_mask_accuracy: 0.7974 - val_mask_loss: 0.1078 - val_parameters_loss: 10.8312 - val_parameters_mae: 11.7947
# Epoch 84/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 193s 69ms/step - loss: 10.7314 - mask_accuracy: 0.7296 - mask_loss: 0.1056 - parameters_loss: 10.6257 - parameters_mae: 11.4281 - val_loss: 10.9356 - val_mask_accuracy: 0.6607 - val_mask_loss: 0.1064 - val_parameters_loss: 10.8312 - val_parameters_mae: 11.6201
# Epoch 84: early stopping
# Restoring model weights from the end of the best epoch: 64.

# %%
pred_params_scaled, pred_mask = modelo.predict(X_test)
pred_params = scaler.inverse_transform(pred_params_scaled)
real_params = scaler.inverse_transform(y_param_test_scaled)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step

# %%
y_param_train.shape, y_param_test.shape, y_mask_train.shape, y_mask_test.shape, rescale_factors.shape
# Out:
# ((89994, 3), (10000, 3), (89994, 501, 2), (10000, 501, 2), (99994,))

# %%
pred_params[:, 1] *= rescale_factors[-10000:]
real_params[:, 1] *= rescale_factors[-10000:]

# %%
sample = 27


plt.figure(figsize=(12,3))
plt.imshow(y_mask_test[sample].reshape(-1, 1002), aspect='auto')
plt.title("Mask Real (Amarelo é a mutação)")
plt.show()

plt.figure(figsize=(12,3))
plt.imshow(pred_mask[sample].reshape(-1, 1002), aspect='auto')
plt.title("Predição")
plt.show()

# %%
erros = np.abs(pred_params - real_params)
mae_por_variavel = np.mean(erros, axis=0)

print("MAE R0:", mae_por_variavel[0])
print("MAE infectious_time:", mae_por_variavel[1])
print("MAE proportion:", mae_por_variavel[2])
# Out:
# MAE R0: 3.3417545939822486
# MAE infectious_time: 12.995175133190614
# MAE proportion: 0.7118601559281368

# %%
erro_relativo = np.mean(np.abs((pred_params - real_params) / real_params), axis=0)

print("Erro relativo R0:", erro_relativo[0])
print("Erro relativo time:", erro_relativo[1])
print("Erro relativo proportion:", erro_relativo[2])
# Out:
# Erro relativo R0: 1.240489772820487
# Erro relativo time: 2.45648566938531
# Erro relativo proportion: 0.2886005513428215

# %%
print(np.corrcoef(real_params[:,0], pred_params[:,0])[0,1])
print(np.corrcoef(real_params[:,1], pred_params[:,1])[0,1])
print(np.corrcoef(real_params[:,2], pred_params[:,2])[0,1])
# Out:
# 0.6653012674164672
# 0.609876799644902
# -0.21202291453193528

# %%
path = "C:\\Users\\JPC\\Documents\\MESTRADO\\Projeto\\gillespie-2\\neural_networks_dot_keras\\29-6\\cross-task_feature_fusion"

modelo.save(path + "\\modelo_mask_29-06.keras")

with open(path + "\\scaler_mask_29-06.pkl", "wb") as f:
    pickle.dump(scaler, f)

with open(path + "\\history_mask_29-06.pkl", "wb") as f:
    pickle.dump(history.history, f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 3
#       1 path = "C:\\Users\\JPC\\Documents\\MESTRADO\\Projeto\\gillespie-2\\neural_networks_dot_keras\\29-6\\cross-task feature fusion"
# ----> 3 modelo.save(path + "\\modelo_mask_29-06.keras")
#       5 with open(path + "\\scaler_mask_29-06.pkl", "wb") as f:
#       6     pickle.dump(scaler, f)
#
# File c:\Users\JPC\anaconda3\envs\phylodeepenv\lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\JPC\anaconda3\envs\phylodeepenv\lib\site-packages\keras\src\saving\saving_lib.py:141, in save_model(model, filepath, weights_format, zipped)
#     139         f.write(zip_filepath.getvalue())
#     140 else:
# --> 141     with open(filepath, "wb") as f:
#     142         _save_model_to_fileobj(model, f, weights_format)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\JPC\\Documents\\MESTRADO\\Projeto\\gillespie-2\\neural_networks_dot_keras\\29-6\\cross-task feature fusion\\modelo_mask_29-06.keras'
