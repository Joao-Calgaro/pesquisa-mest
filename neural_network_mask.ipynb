# %%
import pandas as pd
import csv
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers, Model
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping

# %%
def load_data(v):
    with open(f'mutation_dataset_10-06_v{v}\\simulacoes_com_erro.pkl', 'rb') as arquivo:
        simulacoes_com_erro = pickle.load(arquivo)

    trees_cblv = np.load(f'mutation_dataset_10-06_v{v}\\tree_data.npy')
    trees_cblv = np.delete(trees_cblv, simulacoes_com_erro, axis=0)

    #R_0_1, infectuos time and a taxa relativa 
    # Retornando a segunda coluna (coluna referente ao R_nought)
    # e em segunda transformando a lista em um np.array

    tabela_de_parametros = np.load(f'mutation_dataset_10-06_v{v}\\tabela_parametros.npy')
    tabela_de_parametros = np.delete(tabela_de_parametros, simulacoes_com_erro, axis=0)

    R_nought1 = np.array([sublist[0] for sublist in tabela_de_parametros])
    R_nought2 = np.array([sublist[1] for sublist in tabela_de_parametros])
    infectious_time = np.array([sublist[8] for sublist in tabela_de_parametros])
    proportion_tr11_tr22 = np.array([sublist[10] for sublist in tabela_de_parametros])
    
    rescale_factors = np.load(f'mutation_dataset_10-06_v{v}\\rescale_factor.npy')
    rescale_factors = np.delete(rescale_factors, simulacoes_com_erro)

    infectious_time_div_reascale = np.round(infectious_time / rescale_factors, 3)

    mutation_masks = np.load(f'mutation_dataset_10-06_v{v}\\mutation_masks.npy')
    mutation_masks = np.delete(mutation_masks, simulacoes_com_erro, axis=0)

    vectorized = np.column_stack((R_nought1, infectious_time_div_reascale, proportion_tr11_tr22))

    return trees_cblv, vectorized, mutation_masks, rescale_factors

# %%
X, y_param, y_mask, rescale_factors = load_data(0)

# %%
test_size = 0.1
(X_train, X_test, y_param_train, y_param_test, y_mask_train, y_mask_test) = train_test_split(
    X, y_param, y_mask, test_size=test_size, shuffle=False)

# %%
y_mask_train = y_mask_train.reshape(-1, 501, 2)
y_mask_test = y_mask_test.reshape(-1, 501, 2)

# %%
scaler = StandardScaler()

y_param_train_scaled = scaler.fit_transform(y_param_train)
y_param_test_scaled = scaler.transform(y_param_test)

# %%
# Não repetir quando eu upar dados novos
inputs = layers.Input(shape=X_train[0].shape)
x = layers.Reshape((501, 2))(inputs)
x = layers.Conv1D(filters=50, kernel_size=3, activation='relu', padding='same')(x)
x = layers.Conv1D(filters=50, kernel_size=10, activation='relu', padding='same')(x)


#Mask head
m = layers.Conv1D(filters=32, kernel_size=3, activation='relu', padding='same')(x)
mask_output = layers.Conv1D(filters=2, kernel_size=1, activation='sigmoid', padding='same', name='mask')(m)


#parameters head 
p = layers.MaxPooling1D(pool_size=10)(x)
p = layers.Conv1D( filters=80, kernel_size=10, activation='relu', padding='same' )(p)
p = layers.GlobalAveragePooling1D()(p)
p = layers.Dense(64, activation='elu')(p) 
p = layers.Dense(32, activation='elu')(p) 
p = layers.Dense(16, activation='elu')(p) 
p = layers.Dense(8, activation='elu')(p)
parameter_output = layers.Dense(3, activation='linear', name='parameters')(p)



modelo = Model(inputs=inputs, outputs=[parameter_output, mask_output])
modelo.compile(optimizer='adam', loss={ 'parameters': 'mse', 'mask': 'binary_crossentropy' },
               loss_weights={ 'parameters': 1.0, 'mask': 1.0 }, metrics={ 'parameters': ['mae'], 'mask': ['accuracy'] } )
modelo.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 1002)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 501, 2)    │          0 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 501, 50)   │        350 │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 501, 50)   │     25,050 │ conv1d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 50, 50)    │          0 │ conv1d_1[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 50, 80)    │     40,080 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 80)        │          0 │ conv1d_3[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │      5,184 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 32)        │      2,080 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 16)        │        528 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 8)         │        136 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 501, 32)   │      4,832 │ conv1d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ parameters (Dense)  │ (None, 3)         │         27 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mask (Conv1D)       │ (None, 501, 2)    │         66 │ conv1d_2[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 78,333 (305.99 KB)
#  Trainable params: 78,333 (305.99 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True, verbose=1)

# %%
history = modelo.fit(
    X_train, [y_param_train_scaled, y_mask_train],
    validation_data=(X_test,[y_param_test_scaled, y_mask_test]),
    epochs=100, batch_size=32, callbacks=[early_stop])
# Out:
# Epoch 1/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 159s 55ms/step - loss: 10.7536 - mask_accuracy: 0.5703 - mask_loss: 0.1504 - parameters_loss: 10.6032 - parameters_mae: 2.5837 - val_loss: 10.7330 - val_mask_accuracy: 0.5805 - val_mask_loss: 0.1159 - val_parameters_loss: 10.6180 - val_parameters_mae: 1.7497
# Epoch 2/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 152s 54ms/step - loss: 10.7627 - mask_accuracy: 0.5462 - mask_loss: 0.1164 - parameters_loss: 10.6462 - parameters_mae: 1.6634 - val_loss: 10.7283 - val_mask_accuracy: 0.5760 - val_mask_loss: 0.1112 - val_parameters_loss: 10.6180 - val_parameters_mae: 1.5021
# Epoch 3/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 164s 58ms/step - loss: 10.7225 - mask_accuracy: 0.5669 - mask_loss: 0.1121 - parameters_loss: 10.6104 - parameters_mae: 1.7848 - val_loss: 10.7326 - val_mask_accuracy: 0.4757 - val_mask_loss: 0.1156 - val_parameters_loss: 10.6180 - val_parameters_mae: 16.0675
# Epoch 4/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 161s 57ms/step - loss: 10.7745 - mask_accuracy: 0.5577 - mask_loss: 0.1114 - parameters_loss: 10.6631 - parameters_mae: 15.9525 - val_loss: 10.7355 - val_mask_accuracy: 0.4486 - val_mask_loss: 0.1184 - val_parameters_loss: 10.6180 - val_parameters_mae: 14.8696
# Epoch 5/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 164s 58ms/step - loss: 10.7548 - mask_accuracy: 0.5648 - mask_loss: 0.1108 - parameters_loss: 10.6440 - parameters_mae: 15.6638 - val_loss: 10.7346 - val_mask_accuracy: 0.5251 - val_mask_loss: 0.1176 - val_parameters_loss: 10.6180 - val_parameters_mae: 15.3018
# Epoch 6/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 158s 56ms/step - loss: 10.7458 - mask_accuracy: 0.5771 - mask_loss: 0.1096 - parameters_loss: 10.6362 - parameters_mae: 15.9153 - val_loss: 10.7259 - val_mask_accuracy: 0.5334 - val_mask_loss: 0.1088 - val_parameters_loss: 10.6180 - val_parameters_mae: 16.0982
# Epoch 7/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 166s 59ms/step - loss: 10.7584 - mask_accuracy: 0.5797 - mask_loss: 0.1092 - parameters_loss: 10.6492 - parameters_mae: 16.3080 - val_loss: 10.7270 - val_mask_accuracy: 0.5812 - val_mask_loss: 0.1099 - val_parameters_loss: 10.6180 - val_parameters_mae: 16.8583
# Epoch 8/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 166s 59ms/step - loss: 10.7217 - mask_accuracy: 0.5739 - mask_loss: 0.1080 - parameters_loss: 10.6138 - parameters_mae: 17.0957 - val_loss: 10.7249 - val_mask_accuracy: 0.5187 - val_mask_loss: 0.1078 - val_parameters_loss: 10.6180 - val_parameters_mae: 17.4868
# Epoch 9/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 163s 58ms/step - loss: 10.6963 - mask_accuracy: 0.5585 - mask_loss: 0.1079 - parameters_loss: 10.5884 - parameters_mae: 17.7587 - val_loss: 10.7266 - val_mask_accuracy: 0.5385 - val_mask_loss: 0.1095 - val_parameters_loss: 10.6180 - val_parameters_mae: 18.0272
# Epoch 10/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 168s 60ms/step - loss: 10.7425 - mask_accuracy: 0.5711 - mask_loss: 0.1085 - parameters_loss: 10.6339 - parameters_mae: 18.4960 - val_loss: 10.7268 - val_mask_accuracy: 0.7144 - val_mask_loss: 0.1097 - val_parameters_loss: 10.6180 - val_parameters_mae: 18.7314
# Epoch 11/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 178s 63ms/step - loss: 10.7061 - mask_accuracy: 0.5840 - mask_loss: 0.1074 - parameters_loss: 10.5987 - parameters_mae: 19.2240 - val_loss: 10.7299 - val_mask_accuracy: 0.5814 - val_mask_loss: 0.1129 - val_parameters_loss: 10.6180 - val_parameters_mae: 19.3233
# Epoch 12/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 176s 63ms/step - loss: 10.7277 - mask_accuracy: 0.6015 - mask_loss: 0.1072 - parameters_loss: 10.6205 - parameters_mae: 20.1187 - val_loss: 10.7262 - val_mask_accuracy: 0.6017 - val_mask_loss: 0.1091 - val_parameters_loss: 10.6180 - val_parameters_mae: 20.5003
# Epoch 13/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 164s 58ms/step - loss: 10.7130 - mask_accuracy: 0.6109 - mask_loss: 0.1081 - parameters_loss: 10.6049 - parameters_mae: 20.8298 - val_loss: 10.7249 - val_mask_accuracy: 0.5925 - val_mask_loss: 0.1078 - val_parameters_loss: 10.6180 - val_parameters_mae: 21.6577
# Epoch 14/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 155s 55ms/step - loss: 10.7276 - mask_accuracy: 0.6106 - mask_loss: 0.1068 - parameters_loss: 10.6208 - parameters_mae: 21.8966 - val_loss: 10.7255 - val_mask_accuracy: 0.7451 - val_mask_loss: 0.1085 - val_parameters_loss: 10.6180 - val_parameters_mae: 22.8547
# Epoch 15/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 165s 59ms/step - loss: 10.7372 - mask_accuracy: 0.6153 - mask_loss: 0.1069 - parameters_loss: 10.6303 - parameters_mae: 22.5783 - val_loss: 10.7245 - val_mask_accuracy: 0.6451 - val_mask_loss: 0.1074 - val_parameters_loss: 10.6180 - val_parameters_mae: 22.7543
# Epoch 16/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 157s 56ms/step - loss: 10.7833 - mask_accuracy: 0.6089 - mask_loss: 0.1079 - parameters_loss: 10.6753 - parameters_mae: 23.3507 - val_loss: 10.7259 - val_mask_accuracy: 0.6919 - val_mask_loss: 0.1088 - val_parameters_loss: 10.6180 - val_parameters_mae: 22.9537
# Epoch 17/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 158s 56ms/step - loss: 10.7396 - mask_accuracy: 0.5888 - mask_loss: 0.1074 - parameters_loss: 10.6322 - parameters_mae: 24.2209 - val_loss: 10.7273 - val_mask_accuracy: 0.5677 - val_mask_loss: 0.1102 - val_parameters_loss: 10.6180 - val_parameters_mae: 25.2711
# Epoch 18/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 161s 57ms/step - loss: 10.7218 - mask_accuracy: 0.5791 - mask_loss: 0.1067 - parameters_loss: 10.6150 - parameters_mae: 24.9602 - val_loss: 10.7252 - val_mask_accuracy: 0.7395 - val_mask_loss: 0.1081 - val_parameters_loss: 10.6180 - val_parameters_mae: 25.9472
# Epoch 19/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 167s 59ms/step - loss: 10.6904 - mask_accuracy: 0.5958 - mask_loss: 0.1061 - parameters_loss: 10.5844 - parameters_mae: 25.9791 - val_loss: 10.7241 - val_mask_accuracy: 0.5504 - val_mask_loss: 0.1071 - val_parameters_loss: 10.6180 - val_parameters_mae: 26.1919
# Epoch 20/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 172s 61ms/step - loss: 10.7337 - mask_accuracy: 0.5911 - mask_loss: 0.1074 - parameters_loss: 10.6263 - parameters_mae: 26.7213 - val_loss: 10.7249 - val_mask_accuracy: 0.5264 - val_mask_loss: 0.1079 - val_parameters_loss: 10.6180 - val_parameters_mae: 27.5472
# Epoch 21/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 162s 57ms/step - loss: 10.7592 - mask_accuracy: 0.5970 - mask_loss: 0.1069 - parameters_loss: 10.6523 - parameters_mae: 27.4670 - val_loss: 10.7249 - val_mask_accuracy: 0.5923 - val_mask_loss: 0.1078 - val_parameters_loss: 10.6180 - val_parameters_mae: 28.5113
# Epoch 22/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 150s 53ms/step - loss: 10.7384 - mask_accuracy: 0.5787 - mask_loss: 0.1069 - parameters_loss: 10.6315 - parameters_mae: 28.2616 - val_loss: 10.7239 - val_mask_accuracy: 0.4897 - val_mask_loss: 0.1068 - val_parameters_loss: 10.6180 - val_parameters_mae: 29.6093
# Epoch 23/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 157s 56ms/step - loss: 10.7225 - mask_accuracy: 0.5509 - mask_loss: 0.1066 - parameters_loss: 10.6160 - parameters_mae: 29.0582 - val_loss: 10.7247 - val_mask_accuracy: 0.5666 - val_mask_loss: 0.1077 - val_parameters_loss: 10.6180 - val_parameters_mae: 29.6585
# Epoch 24/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 163s 58ms/step - loss: 10.7429 - mask_accuracy: 0.5674 - mask_loss: 0.1063 - parameters_loss: 10.6365 - parameters_mae: 29.8392 - val_loss: 10.7238 - val_mask_accuracy: 0.5336 - val_mask_loss: 0.1068 - val_parameters_loss: 10.6180 - val_parameters_mae: 30.5236
# Epoch 25/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 163s 58ms/step - loss: 10.7587 - mask_accuracy: 0.5675 - mask_loss: 0.1068 - parameters_loss: 10.6520 - parameters_mae: 30.5900 - val_loss: 10.7239 - val_mask_accuracy: 0.6277 - val_mask_loss: 0.1068 - val_parameters_loss: 10.6180 - val_parameters_mae: 31.4598
# Epoch 26/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 202s 72ms/step - loss: 10.7522 - mask_accuracy: 0.5678 - mask_loss: 0.1072 - parameters_loss: 10.6450 - parameters_mae: 31.4147 - val_loss: 10.7239 - val_mask_accuracy: 0.4087 - val_mask_loss: 0.1068 - val_parameters_loss: 10.6180 - val_parameters_mae: 32.4058
# Epoch 27/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 172s 61ms/step - loss: 10.7443 - mask_accuracy: 0.5640 - mask_loss: 0.1060 - parameters_loss: 10.6384 - parameters_mae: 32.3586 - val_loss: 10.7237 - val_mask_accuracy: 0.4545 - val_mask_loss: 0.1066 - val_parameters_loss: 10.6180 - val_parameters_mae: 32.9605
# Epoch 28/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 162s 57ms/step - loss: 10.7508 - mask_accuracy: 0.5503 - mask_loss: 0.1063 - parameters_loss: 10.6445 - parameters_mae: 33.1154 - val_loss: 10.7251 - val_mask_accuracy: 0.5362 - val_mask_loss: 0.1080 - val_parameters_loss: 10.6180 - val_parameters_mae: 34.2239
# Epoch 29/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 163s 58ms/step - loss: 10.7498 - mask_accuracy: 0.5473 - mask_loss: 0.1064 - parameters_loss: 10.6434 - parameters_mae: 33.7401 - val_loss: 10.7253 - val_mask_accuracy: 0.6652 - val_mask_loss: 0.1082 - val_parameters_loss: 10.6180 - val_parameters_mae: 34.9604
# Epoch 30/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 162s 58ms/step - loss: 10.7465 - mask_accuracy: 0.5457 - mask_loss: 0.1067 - parameters_loss: 10.6397 - parameters_mae: 34.3328 - val_loss: 10.7242 - val_mask_accuracy: 0.5458 - val_mask_loss: 0.1072 - val_parameters_loss: 10.6180 - val_parameters_mae: 34.8728
# Epoch 31/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 162s 57ms/step - loss: 10.7233 - mask_accuracy: 0.5438 - mask_loss: 0.1059 - parameters_loss: 10.6174 - parameters_mae: 35.3165 - val_loss: 10.7256 - val_mask_accuracy: 0.4999 - val_mask_loss: 0.1085 - val_parameters_loss: 10.6180 - val_parameters_mae: 35.2836
# Epoch 32/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 204s 58ms/step - loss: 10.7423 - mask_accuracy: 0.5417 - mask_loss: 0.1056 - parameters_loss: 10.6366 - parameters_mae: 36.1392 - val_loss: 10.7241 - val_mask_accuracy: 0.5620 - val_mask_loss: 0.1070 - val_parameters_loss: 10.6180 - val_parameters_mae: 36.4416
# Epoch 33/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 167s 59ms/step - loss: 10.7365 - mask_accuracy: 0.5374 - mask_loss: 0.1059 - parameters_loss: 10.6306 - parameters_mae: 36.8489 - val_loss: 10.7237 - val_mask_accuracy: 0.4937 - val_mask_loss: 0.1066 - val_parameters_loss: 10.6180 - val_parameters_mae: 37.4021
# Epoch 34/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 170s 60ms/step - loss: 10.7364 - mask_accuracy: 0.5406 - mask_loss: 0.1057 - parameters_loss: 10.6307 - parameters_mae: 37.6505 - val_loss: 10.7238 - val_mask_accuracy: 0.5657 - val_mask_loss: 0.1067 - val_parameters_loss: 10.6180 - val_parameters_mae: 38.4646
# Epoch 35/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 164s 58ms/step - loss: 10.7110 - mask_accuracy: 0.5396 - mask_loss: 0.1056 - parameters_loss: 10.6054 - parameters_mae: 38.4163 - val_loss: 10.7253 - val_mask_accuracy: 0.5106 - val_mask_loss: 0.1082 - val_parameters_loss: 10.6180 - val_parameters_mae: 39.6688
# Epoch 36/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 163s 58ms/step - loss: 10.7038 - mask_accuracy: 0.5316 - mask_loss: 0.1051 - parameters_loss: 10.5987 - parameters_mae: 39.2914 - val_loss: 10.7239 - val_mask_accuracy: 0.5323 - val_mask_loss: 0.1068 - val_parameters_loss: 10.6180 - val_parameters_mae: 40.4379
# Epoch 37/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 163s 58ms/step - loss: 10.7442 - mask_accuracy: 0.5566 - mask_loss: 0.1065 - parameters_loss: 10.6378 - parameters_mae: 39.7377 - val_loss: 10.7244 - val_mask_accuracy: 0.5966 - val_mask_loss: 0.1074 - val_parameters_loss: 10.6180 - val_parameters_mae: 41.0473
# Epoch 38/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 164s 58ms/step - loss: 10.7255 - mask_accuracy: 0.5915 - mask_loss: 0.1054 - parameters_loss: 10.6201 - parameters_mae: 40.8147 - val_loss: 10.7264 - val_mask_accuracy: 0.6262 - val_mask_loss: 0.1093 - val_parameters_loss: 10.6180 - val_parameters_mae: 39.6008
# Epoch 39/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 164s 58ms/step - loss: 10.7457 - mask_accuracy: 0.6318 - mask_loss: 0.1058 - parameters_loss: 10.6399 - parameters_mae: 41.3705 - val_loss: 10.7248 - val_mask_accuracy: 0.6652 - val_mask_loss: 0.1078 - val_parameters_loss: 10.6180 - val_parameters_mae: 42.5959
# Epoch 40/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 165s 59ms/step - loss: 10.7540 - mask_accuracy: 0.6584 - mask_loss: 0.1064 - parameters_loss: 10.6477 - parameters_mae: 42.2742 - val_loss: 10.7238 - val_mask_accuracy: 0.5984 - val_mask_loss: 0.1068 - val_parameters_loss: 10.6180 - val_parameters_mae: 41.2923
# Epoch 41/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 166s 59ms/step - loss: 10.7228 - mask_accuracy: 0.6801 - mask_loss: 0.1052 - parameters_loss: 10.6176 - parameters_mae: 43.0290 - val_loss: 10.7239 - val_mask_accuracy: 0.8152 - val_mask_loss: 0.1069 - val_parameters_loss: 10.6180 - val_parameters_mae: 43.7656
# Epoch 42/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 165s 59ms/step - loss: 10.7227 - mask_accuracy: 0.7156 - mask_loss: 0.1052 - parameters_loss: 10.6175 - parameters_mae: 43.8513 - val_loss: 10.7252 - val_mask_accuracy: 0.8044 - val_mask_loss: 0.1081 - val_parameters_loss: 10.6180 - val_parameters_mae: 45.3765
# Epoch 43/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 165s 59ms/step - loss: 10.7502 - mask_accuracy: 0.7510 - mask_loss: 0.1058 - parameters_loss: 10.6444 - parameters_mae: 44.4733 - val_loss: 10.7238 - val_mask_accuracy: 0.7509 - val_mask_loss: 0.1067 - val_parameters_loss: 10.6180 - val_parameters_mae: 44.6088
# Epoch 44/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 167s 59ms/step - loss: 10.7233 - mask_accuracy: 0.7648 - mask_loss: 0.1061 - parameters_loss: 10.6171 - parameters_mae: 45.0136 - val_loss: 10.7235 - val_mask_accuracy: 0.6673 - val_mask_loss: 0.1064 - val_parameters_loss: 10.6180 - val_parameters_mae: 45.8775
# Epoch 45/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 167s 59ms/step - loss: 10.7548 - mask_accuracy: 0.7966 - mask_loss: 0.1061 - parameters_loss: 10.6488 - parameters_mae: 45.9791 - val_loss: 10.7238 - val_mask_accuracy: 0.8396 - val_mask_loss: 0.1067 - val_parameters_loss: 10.6180 - val_parameters_mae: 46.0460
# Epoch 46/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 167s 59ms/step - loss: 10.7414 - mask_accuracy: 0.8053 - mask_loss: 0.1064 - parameters_loss: 10.6350 - parameters_mae: 46.5914 - val_loss: 10.7256 - val_mask_accuracy: 0.8879 - val_mask_loss: 0.1085 - val_parameters_loss: 10.6180 - val_parameters_mae: 47.7819
# Epoch 47/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 167s 59ms/step - loss: 10.7029 - mask_accuracy: 0.8528 - mask_loss: 0.1055 - parameters_loss: 10.5974 - parameters_mae: 47.4210 - val_loss: 10.7237 - val_mask_accuracy: 0.7388 - val_mask_loss: 0.1066 - val_parameters_loss: 10.6180 - val_parameters_mae: 46.3330
# Epoch 48/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 167s 59ms/step - loss: 10.7443 - mask_accuracy: 0.8437 - mask_loss: 0.1060 - parameters_loss: 10.6383 - parameters_mae: 48.0687 - val_loss: 10.7236 - val_mask_accuracy: 0.8593 - val_mask_loss: 0.1065 - val_parameters_loss: 10.6180 - val_parameters_mae: 48.2078
# Epoch 49/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 169s 60ms/step - loss: 10.7143 - mask_accuracy: 0.8521 - mask_loss: 0.1056 - parameters_loss: 10.6087 - parameters_mae: 48.6022 - val_loss: 10.7236 - val_mask_accuracy: 0.8485 - val_mask_loss: 0.1065 - val_parameters_loss: 10.6180 - val_parameters_mae: 48.8511
# Epoch 50/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 169s 60ms/step - loss: 10.7414 - mask_accuracy: 0.8549 - mask_loss: 0.1061 - parameters_loss: 10.6353 - parameters_mae: 49.3818 - val_loss: 10.7250 - val_mask_accuracy: 0.8098 - val_mask_loss: 0.1079 - val_parameters_loss: 10.6180 - val_parameters_mae: 49.2093
# Epoch 51/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 168s 60ms/step - loss: 10.7222 - mask_accuracy: 0.8493 - mask_loss: 0.1056 - parameters_loss: 10.6166 - parameters_mae: 50.0938 - val_loss: 10.7253 - val_mask_accuracy: 0.8687 - val_mask_loss: 0.1082 - val_parameters_loss: 10.6180 - val_parameters_mae: 51.8023
# Epoch 52/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 169s 60ms/step - loss: 10.7542 - mask_accuracy: 0.8272 - mask_loss: 0.1062 - parameters_loss: 10.6480 - parameters_mae: 50.7194 - val_loss: 10.7251 - val_mask_accuracy: 0.8774 - val_mask_loss: 0.1080 - val_parameters_loss: 10.6180 - val_parameters_mae: 52.2482
# Epoch 53/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 168s 60ms/step - loss: 10.7275 - mask_accuracy: 0.8600 - mask_loss: 0.1054 - parameters_loss: 10.6221 - parameters_mae: 51.4653 - val_loss: 10.7237 - val_mask_accuracy: 0.8455 - val_mask_loss: 0.1066 - val_parameters_loss: 10.6180 - val_parameters_mae: 52.1870
# Epoch 54/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 169s 60ms/step - loss: 10.7411 - mask_accuracy: 0.8561 - mask_loss: 0.1056 - parameters_loss: 10.6354 - parameters_mae: 52.2983 - val_loss: 10.7247 - val_mask_accuracy: 0.8635 - val_mask_loss: 0.1077 - val_parameters_loss: 10.6180 - val_parameters_mae: 53.8822
# Epoch 55/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 170s 60ms/step - loss: 10.7502 - mask_accuracy: 0.8611 - mask_loss: 0.1057 - parameters_loss: 10.6445 - parameters_mae: 52.7954 - val_loss: 10.7240 - val_mask_accuracy: 0.8038 - val_mask_loss: 0.1069 - val_parameters_loss: 10.6180 - val_parameters_mae: 53.6711
# Epoch 56/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 170s 60ms/step - loss: 10.7165 - mask_accuracy: 0.8590 - mask_loss: 0.1055 - parameters_loss: 10.6109 - parameters_mae: 53.4477 - val_loss: 10.7242 - val_mask_accuracy: 0.8832 - val_mask_loss: 0.1072 - val_parameters_loss: 10.6180 - val_parameters_mae: 53.1815
# Epoch 57/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 170s 61ms/step - loss: 10.6882 - mask_accuracy: 0.8550 - mask_loss: 0.1051 - parameters_loss: 10.5831 - parameters_mae: 54.2806 - val_loss: 10.7308 - val_mask_accuracy: 0.9062 - val_mask_loss: 0.1137 - val_parameters_loss: 10.6180 - val_parameters_mae: 57.6311
# Epoch 58/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 170s 61ms/step - loss: 10.7453 - mask_accuracy: 0.8605 - mask_loss: 0.1057 - parameters_loss: 10.6396 - parameters_mae: 54.8199 - val_loss: 10.7234 - val_mask_accuracy: 0.8444 - val_mask_loss: 0.1063 - val_parameters_loss: 10.6180 - val_parameters_mae: 54.6126
# Epoch 59/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 171s 61ms/step - loss: 10.7400 - mask_accuracy: 0.8592 - mask_loss: 0.1054 - parameters_loss: 10.6346 - parameters_mae: 55.3231 - val_loss: 10.7241 - val_mask_accuracy: 0.8099 - val_mask_loss: 0.1071 - val_parameters_loss: 10.6180 - val_parameters_mae: 55.1796
# Epoch 60/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 172s 61ms/step - loss: 10.7479 - mask_accuracy: 0.8452 - mask_loss: 0.1053 - parameters_loss: 10.6425 - parameters_mae: 56.0198 - val_loss: 10.7234 - val_mask_accuracy: 0.8493 - val_mask_loss: 0.1064 - val_parameters_loss: 10.6180 - val_parameters_mae: 56.6389
# Epoch 61/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 171s 61ms/step - loss: 10.7375 - mask_accuracy: 0.8479 - mask_loss: 0.1057 - parameters_loss: 10.6318 - parameters_mae: 56.7218 - val_loss: 10.7244 - val_mask_accuracy: 0.8537 - val_mask_loss: 0.1074 - val_parameters_loss: 10.6180 - val_parameters_mae: 55.4451
# Epoch 62/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 173s 61ms/step - loss: 10.7316 - mask_accuracy: 0.8590 - mask_loss: 0.1052 - parameters_loss: 10.6264 - parameters_mae: 57.2782 - val_loss: 10.7236 - val_mask_accuracy: 0.7704 - val_mask_loss: 0.1065 - val_parameters_loss: 10.6180 - val_parameters_mae: 57.5834
# Epoch 63/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 173s 62ms/step - loss: 10.7461 - mask_accuracy: 0.8518 - mask_loss: 0.1057 - parameters_loss: 10.6404 - parameters_mae: 57.8717 - val_loss: 10.7235 - val_mask_accuracy: 0.8973 - val_mask_loss: 0.1065 - val_parameters_loss: 10.6180 - val_parameters_mae: 57.8599
# Epoch 64/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 175s 62ms/step - loss: 10.7116 - mask_accuracy: 0.8601 - mask_loss: 0.1055 - parameters_loss: 10.6061 - parameters_mae: 58.3169 - val_loss: 10.7238 - val_mask_accuracy: 0.8759 - val_mask_loss: 0.1068 - val_parameters_loss: 10.6180 - val_parameters_mae: 58.7460
# Epoch 65/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 173s 61ms/step - loss: 10.7201 - mask_accuracy: 0.8467 - mask_loss: 0.1053 - parameters_loss: 10.6147 - parameters_mae: 59.1933 - val_loss: 10.7244 - val_mask_accuracy: 0.8115 - val_mask_loss: 0.1073 - val_parameters_loss: 10.6180 - val_parameters_mae: 60.4166
# Epoch 66/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 173s 62ms/step - loss: 10.7489 - mask_accuracy: 0.8441 - mask_loss: 0.1061 - parameters_loss: 10.6428 - parameters_mae: 59.7048 - val_loss: 10.7249 - val_mask_accuracy: 0.8871 - val_mask_loss: 0.1079 - val_parameters_loss: 10.6180 - val_parameters_mae: 60.8699
# Epoch 67/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 176s 63ms/step - loss: 10.6820 - mask_accuracy: 0.8517 - mask_loss: 0.1053 - parameters_loss: 10.5767 - parameters_mae: 60.1752 - val_loss: 10.7237 - val_mask_accuracy: 0.8521 - val_mask_loss: 0.1066 - val_parameters_loss: 10.6180 - val_parameters_mae: 60.0627
# Epoch 68/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 175s 62ms/step - loss: 10.7592 - mask_accuracy: 0.8547 - mask_loss: 0.1054 - parameters_loss: 10.6538 - parameters_mae: 60.5551 - val_loss: 10.7245 - val_mask_accuracy: 0.8356 - val_mask_loss: 0.1074 - val_parameters_loss: 10.6180 - val_parameters_mae: 59.2111
# Epoch 69/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 175s 62ms/step - loss: 10.7315 - mask_accuracy: 0.8648 - mask_loss: 0.1057 - parameters_loss: 10.6257 - parameters_mae: 61.3605 - val_loss: 10.7235 - val_mask_accuracy: 0.8518 - val_mask_loss: 0.1065 - val_parameters_loss: 10.6180 - val_parameters_mae: 61.2893
# Epoch 70/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 175s 62ms/step - loss: 10.7399 - mask_accuracy: 0.8474 - mask_loss: 0.1055 - parameters_loss: 10.6344 - parameters_mae: 62.0351 - val_loss: 10.7235 - val_mask_accuracy: 0.9049 - val_mask_loss: 0.1064 - val_parameters_loss: 10.6180 - val_parameters_mae: 60.8181
# Epoch 71/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 176s 63ms/step - loss: 10.7466 - mask_accuracy: 0.8569 - mask_loss: 0.1051 - parameters_loss: 10.6415 - parameters_mae: 62.0751 - val_loss: 10.7245 - val_mask_accuracy: 0.8259 - val_mask_loss: 0.1074 - val_parameters_loss: 10.6180 - val_parameters_mae: 60.5660
# Epoch 72/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 178s 63ms/step - loss: 10.7668 - mask_accuracy: 0.8582 - mask_loss: 0.1059 - parameters_loss: 10.6609 - parameters_mae: 62.9000 - val_loss: 10.7252 - val_mask_accuracy: 0.9005 - val_mask_loss: 0.1081 - val_parameters_loss: 10.6180 - val_parameters_mae: 64.5220
# Epoch 73/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 176s 63ms/step - loss: 10.7508 - mask_accuracy: 0.8652 - mask_loss: 0.1054 - parameters_loss: 10.6453 - parameters_mae: 63.4633 - val_loss: 10.7234 - val_mask_accuracy: 0.8584 - val_mask_loss: 0.1063 - val_parameters_loss: 10.6180 - val_parameters_mae: 63.9988
# Epoch 74/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 178s 63ms/step - loss: 10.7552 - mask_accuracy: 0.8520 - mask_loss: 0.1058 - parameters_loss: 10.6494 - parameters_mae: 64.2025 - val_loss: 10.7237 - val_mask_accuracy: 0.8643 - val_mask_loss: 0.1066 - val_parameters_loss: 10.6180 - val_parameters_mae: 64.2572
# Epoch 75/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 177s 63ms/step - loss: 10.7439 - mask_accuracy: 0.8635 - mask_loss: 0.1054 - parameters_loss: 10.6384 - parameters_mae: 64.8919 - val_loss: 10.7236 - val_mask_accuracy: 0.8625 - val_mask_loss: 0.1066 - val_parameters_loss: 10.6180 - val_parameters_mae: 65.1625
# Epoch 76/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 179s 64ms/step - loss: 10.7476 - mask_accuracy: 0.8589 - mask_loss: 0.1065 - parameters_loss: 10.6411 - parameters_mae: 65.0332 - val_loss: 10.7258 - val_mask_accuracy: 0.8317 - val_mask_loss: 0.1087 - val_parameters_loss: 10.6180 - val_parameters_mae: 63.3623
# Epoch 77/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 180s 64ms/step - loss: 10.7341 - mask_accuracy: 0.8511 - mask_loss: 0.1055 - parameters_loss: 10.6286 - parameters_mae: 65.9969 - val_loss: 10.7235 - val_mask_accuracy: 0.8704 - val_mask_loss: 0.1065 - val_parameters_loss: 10.6180 - val_parameters_mae: 65.7104
# Epoch 78/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 179s 64ms/step - loss: 10.7223 - mask_accuracy: 0.8474 - mask_loss: 0.1049 - parameters_loss: 10.6174 - parameters_mae: 66.5271 - val_loss: 10.7245 - val_mask_accuracy: 0.8839 - val_mask_loss: 0.1074 - val_parameters_loss: 10.6180 - val_parameters_mae: 67.9620
# Epoch 79/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 178s 63ms/step - loss: 10.7714 - mask_accuracy: 0.8593 - mask_loss: 0.1064 - parameters_loss: 10.6650 - parameters_mae: 66.7395 - val_loss: 10.7245 - val_mask_accuracy: 0.8773 - val_mask_loss: 0.1074 - val_parameters_loss: 10.6180 - val_parameters_mae: 68.6876
# Epoch 80/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 179s 64ms/step - loss: 10.7508 - mask_accuracy: 0.8570 - mask_loss: 0.1055 - parameters_loss: 10.6453 - parameters_mae: 67.5214 - val_loss: 10.7238 - val_mask_accuracy: 0.8211 - val_mask_loss: 0.1068 - val_parameters_loss: 10.6180 - val_parameters_mae: 67.5854
# Epoch 81/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 179s 64ms/step - loss: 10.7332 - mask_accuracy: 0.8474 - mask_loss: 0.1053 - parameters_loss: 10.6280 - parameters_mae: 68.4752 - val_loss: 10.7238 - val_mask_accuracy: 0.8213 - val_mask_loss: 0.1067 - val_parameters_loss: 10.6180 - val_parameters_mae: 68.9844
# Epoch 82/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 205s 65ms/step - loss: 10.7344 - mask_accuracy: 0.8430 - mask_loss: 0.1054 - parameters_loss: 10.6290 - parameters_mae: 68.4654 - val_loss: 10.7233 - val_mask_accuracy: 0.8857 - val_mask_loss: 0.1063 - val_parameters_loss: 10.6180 - val_parameters_mae: 69.4129
# Epoch 83/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 180s 64ms/step - loss: 10.7428 - mask_accuracy: 0.8483 - mask_loss: 0.1057 - parameters_loss: 10.6371 - parameters_mae: 69.1957 - val_loss: 10.7242 - val_mask_accuracy: 0.8684 - val_mask_loss: 0.1072 - val_parameters_loss: 10.6180 - val_parameters_mae: 71.0274
# Epoch 84/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 181s 64ms/step - loss: 10.6853 - mask_accuracy: 0.8555 - mask_loss: 0.1047 - parameters_loss: 10.5806 - parameters_mae: 69.9151 - val_loss: 10.7242 - val_mask_accuracy: 0.8811 - val_mask_loss: 0.1071 - val_parameters_loss: 10.6180 - val_parameters_mae: 70.8266
# Epoch 85/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 184s 65ms/step - loss: 10.7528 - mask_accuracy: 0.8541 - mask_loss: 0.1056 - parameters_loss: 10.6472 - parameters_mae: 70.1140 - val_loss: 10.7242 - val_mask_accuracy: 0.8496 - val_mask_loss: 0.1071 - val_parameters_loss: 10.6180 - val_parameters_mae: 68.5589
# Epoch 86/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 186s 66ms/step - loss: 10.7145 - mask_accuracy: 0.8411 - mask_loss: 0.1055 - parameters_loss: 10.6089 - parameters_mae: 70.5286 - val_loss: 10.7239 - val_mask_accuracy: 0.8534 - val_mask_loss: 0.1068 - val_parameters_loss: 10.6180 - val_parameters_mae: 70.8951
# Epoch 87/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 184s 65ms/step - loss: 10.7544 - mask_accuracy: 0.8606 - mask_loss: 0.1054 - parameters_loss: 10.6490 - parameters_mae: 71.2559 - val_loss: 10.7253 - val_mask_accuracy: 0.8355 - val_mask_loss: 0.1083 - val_parameters_loss: 10.6180 - val_parameters_mae: 69.5005
# Epoch 88/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 181s 64ms/step - loss: 10.7243 - mask_accuracy: 0.8604 - mask_loss: 0.1052 - parameters_loss: 10.6190 - parameters_mae: 71.7043 - val_loss: 10.7236 - val_mask_accuracy: 0.8528 - val_mask_loss: 0.1066 - val_parameters_loss: 10.6180 - val_parameters_mae: 73.0481
# Epoch 89/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 181s 64ms/step - loss: 10.6974 - mask_accuracy: 0.8547 - mask_loss: 0.1048 - parameters_loss: 10.5927 - parameters_mae: 72.4849 - val_loss: 10.7253 - val_mask_accuracy: 0.8864 - val_mask_loss: 0.1082 - val_parameters_loss: 10.6180 - val_parameters_mae: 74.6792
# Epoch 90/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 185s 66ms/step - loss: 10.7360 - mask_accuracy: 0.8512 - mask_loss: 0.1060 - parameters_loss: 10.6300 - parameters_mae: 72.8803 - val_loss: 10.7243 - val_mask_accuracy: 0.8388 - val_mask_loss: 0.1072 - val_parameters_loss: 10.6180 - val_parameters_mae: 71.0598
# Epoch 91/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 188s 67ms/step - loss: 10.7335 - mask_accuracy: 0.8490 - mask_loss: 0.1048 - parameters_loss: 10.6287 - parameters_mae: 73.3112 - val_loss: 10.7232 - val_mask_accuracy: 0.8575 - val_mask_loss: 0.1062 - val_parameters_loss: 10.6180 - val_parameters_mae: 73.1619
# Epoch 92/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 187s 67ms/step - loss: 10.7441 - mask_accuracy: 0.8591 - mask_loss: 0.1051 - parameters_loss: 10.6390 - parameters_mae: 73.8211 - val_loss: 10.7237 - val_mask_accuracy: 0.8117 - val_mask_loss: 0.1066 - val_parameters_loss: 10.6180 - val_parameters_mae: 73.0713
# Epoch 93/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 182s 65ms/step - loss: 10.7178 - mask_accuracy: 0.8405 - mask_loss: 0.1054 - parameters_loss: 10.6125 - parameters_mae: 74.4487 - val_loss: 10.7233 - val_mask_accuracy: 0.8502 - val_mask_loss: 0.1062 - val_parameters_loss: 10.6180 - val_parameters_mae: 74.6022
# Epoch 94/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 183s 65ms/step - loss: 10.7479 - mask_accuracy: 0.8474 - mask_loss: 0.1057 - parameters_loss: 10.6422 - parameters_mae: 74.9927 - val_loss: 10.7246 - val_mask_accuracy: 0.8590 - val_mask_loss: 0.1075 - val_parameters_loss: 10.6180 - val_parameters_mae: 77.3231
# Epoch 95/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 184s 65ms/step - loss: 10.7416 - mask_accuracy: 0.8523 - mask_loss: 0.1055 - parameters_loss: 10.6361 - parameters_mae: 75.5900 - val_loss: 10.7240 - val_mask_accuracy: 0.8483 - val_mask_loss: 0.1069 - val_parameters_loss: 10.6180 - val_parameters_mae: 76.6665
# Epoch 96/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 189s 67ms/step - loss: 10.7311 - mask_accuracy: 0.8520 - mask_loss: 0.1056 - parameters_loss: 10.6255 - parameters_mae: 76.3160 - val_loss: 10.7233 - val_mask_accuracy: 0.8036 - val_mask_loss: 0.1062 - val_parameters_loss: 10.6180 - val_parameters_mae: 76.7601
# Epoch 97/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 185s 66ms/step - loss: 10.7167 - mask_accuracy: 0.8574 - mask_loss: 0.1056 - parameters_loss: 10.6111 - parameters_mae: 76.3262 - val_loss: 10.7237 - val_mask_accuracy: 0.8680 - val_mask_loss: 0.1067 - val_parameters_loss: 10.6180 - val_parameters_mae: 76.3964
# Epoch 98/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 185s 66ms/step - loss: 10.7230 - mask_accuracy: 0.8456 - mask_loss: 0.1048 - parameters_loss: 10.6182 - parameters_mae: 77.2755 - val_loss: 10.7234 - val_mask_accuracy: 0.8887 - val_mask_loss: 0.1063 - val_parameters_loss: 10.6180 - val_parameters_mae: 77.1063
# Epoch 99/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 189s 67ms/step - loss: 10.7354 - mask_accuracy: 0.8565 - mask_loss: 0.1046 - parameters_loss: 10.6308 - parameters_mae: 77.7680 - val_loss: 10.7239 - val_mask_accuracy: 0.8595 - val_mask_loss: 0.1068 - val_parameters_loss: 10.6180 - val_parameters_mae: 79.0979
# Epoch 100/100
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 192s 68ms/step - loss: 10.7482 - mask_accuracy: 0.8489 - mask_loss: 0.1052 - parameters_loss: 10.6430 - parameters_mae: 78.1696 - val_loss: 10.7250 - val_mask_accuracy: 0.8161 - val_mask_loss: 0.1079 - val_parameters_loss: 10.6180 - val_parameters_mae: 75.5589
# Restoring model weights from the end of the best epoch: 91.

# %%
pred_params_scaled, pred_mask = modelo.predict(X_test)
pred_params = scaler.inverse_transform(pred_params_scaled)
real_params = scaler.inverse_transform(y_param_test_scaled)

# %%
y_param_train.shape, y_param_test.shape, y_mask_train.shape, y_mask_test.shape, rescale_factors.shape
# Out:
# ((89994, 3), (10000, 3), (89994, 501, 2), (10000, 501, 2), (99994,))

# %%
pred_params[:, 1] *= rescale_factors[-10000:]
real_params[:, 1] *= rescale_factors[-10000:]

# %%
sample = 16


plt.figure(figsize=(12,3))
plt.imshow(y_mask_test[sample].reshape(-1, 1002), aspect='auto')
plt.title("Mask Real (Amarelo é a mutação)")
plt.show()

plt.figure(figsize=(12,3))
plt.imshow(pred_mask[sample].reshape(-1, 1002), aspect='auto')
plt.title("Predição")
plt.show()

# %%
erros = np.abs(pred_params - real_params)
mae_por_variavel = np.mean(erros, axis=0)

print("MAE R0:", mae_por_variavel[0])
print("MAE infectious_time:", mae_por_variavel[1])
print("MAE proportion:", mae_por_variavel[2])
# Out:
# MAE R0: 113.8344172419616
# MAE infectious_time: 171.54495686492518
# MAE proportion: 16.585471532820808

# %%
erro_relativo = np.mean(np.abs((pred_params - real_params) / real_params), axis=0)

print("Erro relativo R0:", erro_relativo[0])
print("Erro relativo time:", erro_relativo[1])
print("Erro relativo proportion:", erro_relativo[2])
# Out:
# Erro relativo R0: 51.230854949939484
# Erro relativo time: 32.261951044587526
# Erro relativo proportion: 7.71674943419088

# %%
print(np.corrcoef(real_params[:,0], pred_params[:,0])[0,1])
print(np.corrcoef(real_params[:,1], pred_params[:,1])[0,1])
print(np.corrcoef(real_params[:,2], pred_params[:,2])[0,1])
# Out:
# -0.6660040600286662
# -0.44737116331925114
# -0.0821382195566929

# %%
modelo.save("modelo_mask_07-06.keras")

with open("scaler_mask_07-06.pkl", "wb") as f:
    pickle.dump(scaler, f)

with open("history_mask_07-06.pkl", "wb") as f:
    pickle.dump(history.history, f)

# %%
with open('mutation_dataset_10-06\\simulacoes_com_erro.pkl', 'rb') as arquivo:
        conferir = pickle.load(arquivo)

print(conferir)
# Out:
# [57492, 67801, 68964, 71722, 77362, 91641]
